# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/AI/generative Modules/techinal work /Ayush_gupta/ayush
# Out:
# /content/drive/My Drive/ayush

# %%
# !git clone https://github.com/Yijunmaverick/CartoonGAN-Test-Pytorch-Torch
# Out:
# Cloning into 'CartoonGAN-Test-Pytorch-Torch'...
# remote: Enumerating objects: 151, done.
# remote: Total 151 (delta 0), reused 0 (delta 0), pack-reused 151
# Receiving objects: 100% (151/151), 11.99 MiB | 17.10 MiB/s, done.
# Resolving deltas: 100% (56/56), done.

# %%
cd /content/drive/My Drive/AI/generative Modules/techinal work /Ayush_gupta/ayush/CartoonGAN-Test-Pytorch-Torch
# Out:
# /content/drive/My Drive/ayush/CartoonGAN-Test-Pytorch-Torch

# %%
# !sh pretrained_model/download_t7.sh
# Out:
# --2020-04-06 07:40:44--  http://vllab1.ucmerced.edu/~yli62/CartoonGAN/torch_t7/Hayao_net_G_float.t7
# Resolving vllab1.ucmerced.edu (vllab1.ucmerced.edu)... 169.236.184.68
# Connecting to vllab1.ucmerced.edu (vllab1.ucmerced.edu)|169.236.184.68|:80... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# --2020-04-06 07:40:44--  http://vllab1.ucmerced.edu/~yli62/CartoonGAN/torch_t7/Hosoda_net_G_float.t7
# Resolving vllab1.ucmerced.edu (vllab1.ucmerced.edu)... 169.236.184.68
# Connecting to vllab1.ucmerced.edu (vllab1.ucmerced.edu)|169.236.184.68|:80... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# --2020-04-06 07:40:44--  http://vllab1.ucmerced.edu/~yli62/CartoonGAN/torch_t7/Paprika_net_G_float.t7
# Resolving vllab1.ucmerced.edu (vllab1.ucmerced.edu)... 169.236.184.68
# ...

# %%
# !python test.py --input_dir ./test_img --style Hosoda --gpu 0
# Out:
# GPU mode
# test.py:61: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   input_image = Variable(input_image, volatile=True).cuda()
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Done!
